# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from collections import Counter

# %matplotlib inline

# %% [markdown]
# # Loading all DataSets

# %%
blob_df = pd.read_csv("blob.csv")
dart_df = pd.read_csv("dart.csv")
outliers_df = pd.read_csv("outliers.csv")
spiral2_df = pd.read_csv("spiral2.csv")
basic2_df = pd.read_csv("basic2.csv")
boxes3_df = pd.read_csv("boxes3.csv")

# %% [markdown]
# # Visualizing All DataSets

# %%
fig, axes = plt.subplots(nrows=2, ncols=3,figsize=(13,13))
fig.suptitle('EXERCISE DATA SETS\n', size = 18)

axes[0,0].scatter(blob_df['x'], blob_df['y'], c=blob_df['color'], s=10, cmap = "Set3")
axes[0,0].set_title("Blob");

axes[0,1].scatter(dart_df['x'], dart_df['y'], c=dart_df['color'], s=10, cmap = "Set3")
axes[0,1].set_title("Dart");

axes[0,2].scatter(basic2_df['x'], basic2_df['y'], c=basic2_df['color'], s=10, cmap = "Set3")
axes[0,2].set_title("Basic");

axes[1,0].scatter(outliers_df['x'], outliers_df['y'], c=outliers_df['color'], s=10, cmap = "Set3")
axes[1,0].set_title("Outliers");

axes[1,1].scatter(spiral2_df['x'], spiral2_df['y'], c=spiral2_df['color'], s=10, cmap = "Set3")
axes[1,1].set_title("Spiral");

axes[1,2].scatter(boxes3_df['x'], boxes3_df['y'], c=boxes3_df['color'], s=10, cmap = "Set3")
axes[1,2].set_title("Boxes");

plt.tight_layout()

# %% [markdown]
# # KMeans

# %%
df_blob_kmeans = blob_df.copy()
df_dart_kmeans = dart_df.copy()
df_basic_kmeans = basic2_df.copy()
df_outliers_kmeans = outliers_df.copy()
df_spiral2_kmeans = spiral2_df.copy()
df_boxes3_kmeans = boxes3_df.copy()

# %%
df_blob_kmeans.drop(['color'], axis = 1, inplace =True)
df_dart_kmeans.drop(['color'], axis = 1, inplace =True)
df_basic_kmeans.drop(['color'], axis = 1, inplace =True)
df_outliers_kmeans.drop(['color'], axis = 1, inplace =True)
df_spiral2_kmeans.drop(['color'], axis = 1, inplace =True)
df_boxes3_kmeans.drop(['color'], axis = 1, inplace =True)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 6, init = 'k-means++', random_state = 42)

kmeans_blob = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
kmeans_dart = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42)
kmeans_basic = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
kmeans_outliers = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
kmeans_spiral2 = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42)
kmeans_boxes3 = KMeans(n_clusters = 12, init = 'k-means++', random_state = 42)

y_kmeans_blob = kmeans_blob.fit_predict(df_blob_kmeans)
y_kmeans_dart = kmeans_dart.fit_predict(df_dart_kmeans)
y_kmeans_basic = kmeans_basic.fit_predict(df_basic_kmeans)
y_kmeans_outliers = kmeans_outliers.fit_predict(df_outliers_kmeans)
y_kmeans_spiral2 = kmeans_spiral2.fit_predict(df_spiral2_kmeans)
y_kmeans_boxes3 = kmeans_boxes3.fit_predict(df_boxes3_kmeans)

# %%
df_blob_kmeans['Cluster'] = y_kmeans_blob
df_dart_kmeans['Cluster'] = y_kmeans_dart
df_basic_kmeans['Cluster'] = y_kmeans_basic
df_outliers_kmeans['Cluster'] = y_kmeans_outliers
df_spiral2_kmeans['Cluster'] = y_kmeans_spiral2
df_boxes3_kmeans['Cluster'] = y_kmeans_boxes3

# %%
fig, axes = plt.subplots(nrows=6, ncols=2,figsize=(10,30))
fig.suptitle('ANSWER vs K-Means\n', size = 18)

axes[0,0].scatter(blob_df['x'], blob_df['y'], c=blob_df['color'], s=10, cmap = "Set3")
axes[0,0].set_title("Answer Blob");
axes[0,1].scatter(df_blob_kmeans['x'], df_blob_kmeans['y'], c=df_blob_kmeans['Cluster'], s=10, cmap = "Set3")
axes[0,1].set_title("K-Means Blob");


axes[1,0].scatter(dart_df['x'], dart_df['y'], c=dart_df['color'], s=10, cmap = "Set3")
axes[1,0].set_title("Answer Dart");
axes[1,1].scatter(df_dart_kmeans['x'], df_dart_kmeans['y'], c=df_dart_kmeans['Cluster'], s=10, cmap = "Set3")
axes[1,1].set_title("K-Means Dart");

axes[2,0].scatter(basic2_df['x'], basic2_df['y'], c=basic2_df['color'], s=10, cmap = "Set3")
axes[2,0].set_title("Answer Basic");
axes[2,1].scatter(df_basic_kmeans['x'], df_basic_kmeans['y'], c=df_basic_kmeans['Cluster'], s=10, cmap = "Set3")
axes[2,1].set_title("K-Means Basic");

axes[3,0].scatter(outliers_df['x'], outliers_df['y'], c=outliers_df['color'], s=10, cmap = "Set3")
axes[3,0].set_title("Answer Outliers");
axes[3,1].scatter(df_outliers_kmeans['x'], df_outliers_kmeans['y'], c=df_outliers_kmeans['Cluster'], s=10, cmap = "Set3")
axes[3,1].set_title("K-Means Outliers");

axes[4,0].scatter(spiral2_df['x'], spiral2_df['y'], c=spiral2_df['color'], s=10, cmap = "Set3")
axes[4,0].set_title("Answer Spiral");
axes[4,1].scatter(df_spiral2_kmeans['x'], df_spiral2_kmeans['y'], c=df_spiral2_kmeans['Cluster'], s=10, cmap = "Set3")
axes[4,1].set_title("K-Means Spiral");

axes[5,0].scatter(boxes3_df['x'], boxes3_df['y'], c=boxes3_df['color'], s=10, cmap = "Set3")
axes[5,0].set_title("Answer Boxes");
axes[5,1].scatter(df_boxes3_kmeans['x'], df_boxes3_kmeans['y'], c=df_boxes3_kmeans['Cluster'], s=10, cmap = "Set3")
axes[5,1].set_title("K-Means Boxes");

plt.tight_layout()

# %% [markdown]
# # KMedoid

# %%
df_blob_kmedoid = blob_df.copy()
df_dart_kmedoid = dart_df.copy()
df_basic_kmedoid = basic2_df.copy()
df_outliers_kmedoid = outliers_df.copy()
df_spiral2_kmedoid = spiral2_df.copy()
df_boxes3_kmedoid = boxes3_df.copy()
df_blob_kmedoid.drop(['color'], axis = 1, inplace =True)
df_dart_kmedoid.drop(['color'], axis = 1, inplace =True)
df_basic_kmedoid.drop(['color'], axis = 1, inplace =True)
df_outliers_kmedoid.drop(['color'], axis = 1, inplace =True)
df_spiral2_kmedoid.drop(['color'], axis = 1, inplace =True)
df_boxes3_kmedoid.drop(['color'], axis = 1, inplace =True)

# %%
y_kmedoids_blob = kmedoids(df_blob_kmedoid.values, 4)
y_kmedoids_dart = kmedoids(df_dart_kmedoid.values, 2)
y_kmedoids_basic = kmedoids(df_basic_kmedoid.values, 5)
y_kmedoids_outliers = kmedoids(df_outliers_kmedoid.values, 3)
y_kmedoids_spiral2 = kmedoids(df_spiral2_kmedoid.values, 2)
y_kmedoids_boxes3 = kmedoids(df_boxes3_kmedoid.values, 12)

# %%
df_blob_kmedoid['Cluster'] = y_kmedoids_blob
df_dart_kmedoid['Cluster'] = y_kmedoids_dart
df_basic_kmedoid['Cluster'] = y_kmedoids_basic
df_outliers_kmedoid['Cluster'] = y_kmedoids_outliers
df_spiral2_kmedoid['Cluster'] = y_kmedoids_spiral2
df_boxes3_kmedoid['Cluster'] = y_kmedoids_boxes3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-60c89f317362> in <module>
# ----> 1 df_blob_kmedoid['Cluster'] = y_kmedoids_blob
#       2 # df_dart_kmedoid['Cluster'] = y_kmedoids_dart
#       3 # df_basic_kmedoid['Cluster'] = y_kmedoids_basic
#       4 # df_outliers_kmedoid['Cluster'] = y_kmedoids_outliers
#       5 # df_spiral2_kmedoid['Cluster'] = y_kmedoids_spiral2
#
# c:\Users\Nadeem\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3957         else:
#    3958             # set column
# -> 3959             self._set_item(key, value)
#    3960
#    3961     def _setitem_slice(self, key: slice, value) -> None:
#
# c:\Users\Nadeem\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    4150         ensure homogeneity.
#    4151         """
# -> 4152         value = self._sanitize_column(value)
#    4153
#    4154         if (
#
# c:\Users\Nadeem\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4876
#    4877         if is_list_like(value):
# -> 4878             com.require_length_match(value, self.index)
#    4879         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4880
#
# c:\Users\Nadeem\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     574     """
#     575     if len(data) != len(index):
# --> 576         raise ValueError(
#     577             "Length of values "
#     578             f"({len(data)}) "
#
# ValueError: Length of values (2) does not match length of index (4086)

# %%
fig, axes = plt.subplots(nrows=6, ncols=2,figsize=(10,30))
fig.suptitle('ANSWER vs K-Medoid\n', size = 18)

axes[0,0].scatter(blob_df['x'], blob_df['y'], c=blob_df['color'], s=10, cmap = "Set3")
axes[0,0].set_title("Answer Blob");
axes[0,1].scatter(df_blob_kmedoid['x'], df_blob_kmedoid['y'], c=df_blob_kmedoid['Cluster'], s=10, cmap = "Set3")
axes[0,1].set_title("K-Medoid Blob");


axes[1,0].scatter(dart_df['x'], dart_df['y'], c=dart_df['color'], s=10, cmap = "Set3")
axes[1,0].set_title("Answer Dart");
axes[1,1].scatter(df_dart_kmedoid['x'], df_dart_kmedoid['y'], c=df_dart_kmedoid['Cluster'], s=10, cmap = "Set3")
axes[1,1].set_title("K-Medoid Dart");

axes[2,0].scatter(basic2_df['x'], basic2_df['y'], c=basic2_df['color'], s=10, cmap = "Set3")
axes[2,0].set_title("Answer Basic");
axes[2,1].scatter(df_basic_kmedoid['x'], df_basic_kmedoid['y'], c=df_basic_kmedoid['Cluster'], s=10, cmap = "Set3")
axes[2,1].set_title("K-Medoid Basic");

axes[3,0].scatter(outliers_df['x'], outliers_df['y'], c=outliers_df['color'], s=10, cmap = "Set3")
axes[3,0].set_title("Answer Outliers");
axes[3,1].scatter(df_outliers_kmedoid['x'], df_outliers_kmedoid['y'], c=df_outliers_kmedoid['Cluster'], s=10, cmap = "Set3")
axes[3,1].set_title("K-Medoid Outliers");

axes[4,0].scatter(spiral2_df['x'], spiral2_df['y'], c=spiral2_df['color'], s=10, cmap = "Set3")
axes[4,0].set_title("Answer Spiral");
axes[4,1].scatter(df_spiral2_kmedoid['x'], df_spiral2_kmedoid['y'], c=df_spiral2_kmedoid['Cluster'], s=10, cmap = "Set3")
axes[4,1].set_title("K-Medoid Spiral");

axes[5,0].scatter(boxes3_df['x'], boxes3_df['y'], c=boxes3_df['color'], s=10, cmap = "Set3")
axes[5,0].set_title("Answer Boxes");
axes[5,1].scatter(df_boxes3_kmedoid['x'], df_boxes3_kmedoid['y'], c=df_boxes3_kmedoid['Cluster'], s=10, cmap = "Set3")
axes[5,1].set_title("K-Medoid Boxes");

plt.tight_layout()

# %% [markdown]
# # KMode

# %%
df_blob_kmode = blob_df.copy()
df_dart_kmode = dart_df.copy()
df_basic_kmode = basic2_df.copy()
df_outliers_kmode = outliers_df.copy()
df_spiral2_kmode = spiral2_df.copy()
df_boxes3_kmode = boxes3_df.copy()
df_blob_kmode.drop(['color'], axis = 1, inplace =True)
df_dart_kmode.drop(['color'], axis = 1, inplace =True)
df_basic_kmode.drop(['color'], axis = 1, inplace =True)
df_outliers_kmode.drop(['color'], axis = 1, inplace =True)
df_spiral2_kmode.drop(['color'], axis = 1, inplace =True)
df_boxes3_kmode.drop(['color'], axis = 1, inplace =True)

# %%
def k_modes(X, n_clusters, max_iter=100):
    centroids = X[np.random.choice(len(X), n_clusters), :]
    
    for i in range(max_iter):
        distances = np.zeros((len(X), n_clusters))
        for j in range(n_clusters):
            distances[:, j] = np.sum(X != centroids[j], axis=1)
        
        clusters = np.argmin(distances, axis=1)
        
        for j in range(n_clusters):
            mask = clusters == j
            centroids[j, :] = np.array([np.argmax(np.bincount(X[mask, k])) for k in range(X.shape[1])])
    
    return clusters, centroids
